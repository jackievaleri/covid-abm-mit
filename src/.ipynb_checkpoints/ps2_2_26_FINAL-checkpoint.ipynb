# %% [markdown]
# <div style="font-size: smaller; color: #808080; text-align: center; display: block;">MIT - 6.802 / 6.874 / 20.390 / 20.490 / HST.506 Computational Systems Biology: Deep Learning in the Life Sciences - Spring 2019</div>
#
# # Problem Set 2: Transcription factor binding site prediction with CNNs (and RNNs)

# %% [markdown]
# In this problem set we are going to train a CNN to classify the binding sequences of the transcription factor CTCF. The positive examples are 101 bp DNA sequences centered at CTCF ChIP-seq peaks from GM12878 cells. Negative sequences are generated by permuting the nucleotides in the positive sequences while keeping the di-nucleotide frequency. All the sequences have been embedded using one-hot encoding. Unlike problem set 1, which was a multi-class classification task (10 digits), problem set 2 is a binary classification task (CTCF is binding, CTCF is not binding).
#
# Concepts and techniques relevant to this problem set:
# - convolutional layers
# - recurrent layers (for 6.874 students only)
# - model evaluation with ROC and precision-recall curves
# - model serialization and deserialization (storing models on disk)
# - grid search as hyperparameter optimization technique

# %%
# import libraries, set random seed for reproducibility, and print TensorFlow version

# if libraries are missing:
# !pip install tensorflow
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install h5py
# !pip install sklearn
# !pip install tqdm

import random
import sys
import os
import shutil

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import h5py
import sklearn.metrics
from tqdm import tqdm_notebook as tqdm
import tensorflow as tf

random.seed(0)
print(tf.__version__)
# Out:
# Collecting tqdm
#   Downloading https://files.pythonhosted.org/packages/6c/4b/c38b5144cf167c4f52288517436ccafefe9dc01b8d1c190e18a6b154cd4a/tqdm-4.31.1-py2.py3-none-any.whl (48kB)
#     100% |████████████████████████████████| 51kB 2.0MB/s ta 0:00:01
# Installing collected packages: tqdm
# Successfully installed tqdm-4.31.1
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 1.8.0

# %%
# function to load the data embedded in the previous problem and their labels 
def load_data(prefix='', path='./'):
    training_set = h5py.File(os.path.join(path, prefix + 'train.h5'), 'r')
    validation_set = h5py.File(os.path.join(path, prefix + 'valid.h5'), 'r')
    test_set = h5py.File(os.path.join(path, prefix + 'test.h5'), 'r')
    
    return(training_set['data'][:], training_set['label'][:],
           validation_set['data'][:], validation_set['label'][:],
           test_set['data'][:], test_set['label'][:])

# %%
# Load the data
SEQ_LEN = 101
NUM_BASES = 4
NUM_CLASSES = 2

x_tr, y_tr, x_va, y_va, x_te, y_te = load_data()
print("training set:", x_tr.shape)
print("validation set:", x_va.shape)
print("test set:", x_te.shape)
# Out:
# ('training set:', (60755, 1, 101, 4))
# ('validation set:', (8680, 1, 101, 4))
# ('test set:', (17359, 1, 101, 4))

# %% [markdown]
# ## Problem 1: Construct a CNN with given specifications (50 points)
#
# Implement a CNN model with the following architecture:
# 1. one convolutional layer with 32 kernels (filters) of width 11 and height 1, step size of 1 and ReLU activation. The input should be padded so that the output has the same size as the original input.
# 2. one max-pooling layer with pooling size of 2
# 3. flatten the tensor to prepare it for the fully connected layer
# 4. one fully connected layer with 64 neurons and ReLU activation
# 5. one dropout layer with a `dropout_rate` (dropout rate = 1 - keep probability)
# 6. one fully connected layer with 2 neurons and sigmoid activation
# 7. all the weights (not the biases) in the network should be returned in list `weights` (for L2 regularization in function `cnn_loss`)
#
# About weight initialization:
# - do not initialize weights with zeros or other constant values!
# - use random initialization to [break symmetries](https://medium.com/usf-msds/deep-learning-best-practices-1-weight-initialization-14e5c0295b94), e.g.
#   - zero-centered Gaussian with low variance (e.g., $\sigma = 0.01$)
#   - zero-centered truncated Gaussian with low variance (e.g., $\sigma = 0.01$)
#   - Xavier intialization
#   - He initialization
#
# About bias initialization:
# - can be initialized to constant value, also zero (since weight initialization breaks symmetry)
# - commonly initialized to 0.1, 0.01, 0.0, 1.0
#
# Useful functions:
# - [tf.truncated_normal](https://www.tensorflow.org/api_docs/python/tf/truncated_normal)
# - [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d)
# - [tf.nn.bias_add](https://www.tensorflow.org/api_docs/python/tf/nn/bias_add)
# - [tf.nn.relu](https://www.tensorflow.org/api_docs/python/tf/nn/relu)
# - [tf.nn.max_pool](https://www.tensorflow.org/api_docs/python/tf/nn/max_pool)
# - [tf.nn.dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout)
# - [tf.nn.softmax](https://www.tensorflow.org/api_docs/python/tf/nn/softmax)
# - [tf.matmul](https://www.tensorflow.org/api_docs/python/tf/matmul)

# %%
def cnn_model(x_ph, dropout_rate):
    ################################################################################ 
    # Implement a CNN with the required structure and initialize all the variables:
    # Arguments:
    # - x_ph: one-hot encoded DNA input data / placeholder of shape [?, 1, 101, 4]
    # - dropout_rate: dropout rate (1 - keep probability) of dropout layer
    # Return values:
    # - y_hat_op: class probabilities operator (our predicted y, sigmoid(z_op)) of shape [?, 2]
    # - z_op: unscaled log probabilities operator (output of last matrix multiplication,
    #      before activation function) of shape [?, 2]
    # - weights: a list of all tf.Variable weight matrices
    ################################################################################
    # x_ph: [batch, in_height, in_width, in_channels] -> [?, 1, 101, 4]
    # conv layer filter: [filter_height, filter_width, in_channels, out_channels] -> [1, 11, 4, 32]
    conv_filter_height = 1
    conv_filter_width = 11
    in_channels = 4
    out_channels = 32
    fc_units = 64
    max_pool_stride = 2
    ################################################################################
    #                            BEGINNING OF YOUR CODE                            #
    ################################################################################

    # 1) first convolutional layer with 32 kernels of width 11 & height 1, step size 1, ReLu activation
    # also has zero padding and ReLu activation
    conv_weight_matrix_size = [conv_filter_height, conv_filter_width, in_channels, out_channels]
    conv_weights = tf.Variable(tf.truncated_normal(conv_weight_matrix_size, mean=0.0, stddev=0.01))
    strides = 2
    conv1 = tf.nn.conv2d(x_ph, conv_weights, strides=[1, strides, strides, 1], padding='SAME') 
    conv1_bias = tf.Variable(tf.constant(0.1, shape = [out_channels]))
    conv1 = tf.nn.bias_add(conv1, conv1_bias)
    conv1 = tf.nn.relu(conv1)
    
    # 2) one max pooling layer with pool size of 2
    conv1 = tf.nn.max_pool(conv1, ksize=[1, max_pool_stride, max_pool_stride, 1], strides=[1, 1, 1, 1], padding='SAME')
    
    # 3) flatten tensor to prepare for fully connected layer
    flattened_dim_size = 51 * 32
    full1 = tf.reshape(conv1, [-1, flattened_dim_size])
    full1_weight_matrix_size = [flattened_dim_size, fc_units]
    full1_weights = tf.Variable(tf.truncated_normal(full1_weight_matrix_size, mean=0.0, stddev=0.01))
    
    # 4) fully connected layer with 64 neurons and ReLu activation
    full1_bias = tf.Variable(tf.constant(0.1, shape =[fc_units]))
    full1 = tf.add(tf.matmul(full1, full1_weights), full1_bias)
    full1 = tf.nn.relu(full1)
    
    # 5) one dropout layer w/ dropout rate = 1 - keep_prob
    full1 = tf.nn.dropout(full1, 1 - dropout_rate)
    
    # 6) second fully connected layer with 2 neurons and softmax
    full2_bias = tf.Variable(tf.constant(0.1, shape =[max_pool_stride]))
    full2_weight_matrix_size = [fc_units, max_pool_stride]
    full2_weights = tf.Variable(tf.truncated_normal(full2_weight_matrix_size, mean=0.0, stddev=0.01))
    
    z_op = tf.add(tf.matmul(full1, full2_weights), full2_bias)
    y_hat_op = tf.nn.softmax(z_op)
    
    # 7) all the weights returned in list weights for L2 reg later on in cnn_loss
    weights = [conv_weights, full1_weights, full2_weights]
    
    ################################################################################
    #                               END OF YOUR CODE                               #
    ################################################################################
    return y_hat_op, z_op, weights

# %% [markdown]
# Useful functions:
# - [tf.nn.softmax_cross_entropy_with_logits_v2](https://www.tensorflow.org/api_docs/python/tf/nn/softmax_cross_entropy_with_logits_v2)
# - [tf.nn.l2_loss](https://www.tensorflow.org/api_docs/python/tf/nn/l2_loss)
# - [tf.reduce_mean](https://www.tensorflow.org/api_docs/python/tf/reduce_mean)

# %%
def cnn_loss(z_op, y_ph, weights, l2_coefficient):
    ################################################################################ 
    # Implement a loss operator, which calculates an L2 regularized cross entropy 
    # loss 
    # Arguments:
    # - z_op: unscaled log probabilities (output of last layer) of shape [?, 2]
    # - y_ph: labels / placeholder of shape [?, 2]
    # - weights: list of all weight tf.Variables
    # - l2_coefficient: coefficient lambda for L2 regularization of weights
    # Return values:
    # - loss_op: the loss operator
    ################################################################################
    #                            BEGINNING OF YOUR CODE                            #
    ################################################################################

    # Original loss function
    loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits = z_op, labels = y_ph))
    
    # Now add on loss function using L2 Regularization to the original loss function
    # first weight
    regularizer_1 = tf.nn.l2_loss(weights[0])
    
    # second weight
    regularizer_2 = tf.nn.l2_loss(weights[1])
    
    # third weight
    regularizer_3 = tf.nn.l2_loss(weights[2])
    
    loss_op = loss_op + (l2_coefficient * regularizer_1) + (l2_coefficient * regularizer_2) + (l2_coefficient * regularizer_3)
    
    ################################################################################
    #                               END OF YOUR CODE                               #
    ################################################################################
    return loss_op

# %% [markdown]
# ## Problem 2: Implement the training loop (30 points)
#
# In order to perform hyper-parameter search later, we need a training function that takes the hyperparameter configuration as input parameter.
#
# Implement `training`:
# - initialize all variables
# - train for `num_epochs` epochs. In each epoch, train on mini-batch of size `batch_size`.
# - at the end of each epoch:
#   - calculate validation loss
#   - save model if validation loss is lower than validation loss of previous epochs (inputs: `x_ph`, `y_ph`; output: `y_hat_op`, `loss_op`)
#
# Useful functions:
# - [tf.saved_model.simple_save](https://www.tensorflow.org/api_docs/python/tf/saved_model/simple_save)
#
# [How to save a model with simple_save](https://stackoverflow.com/questions/33759623/tensorflow-how-to-save-restore-a-model/50852627#50852627). Don't forget to name operators that you what to restore later (e.g., `y_hat_op`).

# %%
def training(x_train, y_train, x_val, y_val, hyperparam_config, num_epochs, batch_size,
             save_model=True, model_dir='models/best_model'): 
    ################################################################################
    # Arguments:
    # - x_train: input training set
    # - y_train: label training set
    # - x_val: input validation set
    # - y_val: label validation set
    # - hyperparam_config: a dictionary that stores a hyperparameter configuration,
    #                      including:
    #                      - "dropout_rate": dropout rate (1 - keep probability),
    #                      - "l2": coefficient lambda for L2 regularization,
    #                      - "lr": learning rate for RMSProp optimizer
    # - num_epochs: number of epochs to train
    # - batch_size: training mini-batch size
    # - best_model_dir: location where model will be saved
    # Return values:
    # - best_loss: best validation loss
    ################################################################################
    tf.reset_default_graph()
    
    # define input and output placeholders
    # TF uses NHWC: the data is stored in the order of [batch, in_height, in_width, in_channels]
    # DNA is one-dimensional (height = 1, width = 101) with four channels for the four bases A, C, G, T
    x_ph = tf.placeholder("float", [None, 1, SEQ_LEN, NUM_BASES], name="x_ph")
    y_ph = tf.placeholder("float", [None, NUM_CLASSES], name="y_ph")

    # model
    y_hat_op, z_op, weights = cnn_model(x_ph, hyperparam_config['dropout_rate'])
    
    # loss
    loss_op = cnn_loss(z_op, y_ph, weights, hyperparam_config['l2'])

    # optimizer
    optimizer_op = tf.train.RMSPropOptimizer(hyperparam_config['lr'], 0.9).minimize(loss_op)
     
    # Implement training loop
    # - loop through training data num_epochs times
    # - after each epoch, calculate loss on validation set (x_val, y_val)
    # - if save_model: save model with lowest validation loss to disk (model_dir)
    # - (delete previous best model)
    # - return lowest validation loss
    ################################################################################
    #                            BEGINNING OF YOUR CODE                            #
    ################################################################################
    # initialize variables & import necessary things
    from tensorflow.python.saved_model import tag_constants
    best_loss = 100000000000
    
    # create a session to evaluate computational graph
    with tf.Session() as sess:
      sess.run(tf.global_variables_initializer())
      
      # loop through training data num_epochs times
      for epoch in range(num_epochs): 
        batch_nums = int(x_train.shape[0] / batch_size)

        # loop through each of the mini batches and train on them
        for step in range(batch_nums):
          offset = (step * batch_size) % (x_train.shape[0] - batch_size)
          batch_x = x_train[offset:(offset + batch_size), :]
          batch_y = y_train[offset:(offset + batch_size)]
          _, batch_loss = sess.run([optimizer_op, loss_op], feed_dict = {x_ph: batch_x, y_ph: batch_y})
        
        # at the end of each epoch, calculate the loss and update best loss
        loss = sess.run(loss_op, feed_dict={x_ph: x_val, y_ph: y_val})
        best_loss = min(loss, best_loss)
        
        # if save_model: save model with lowest validation loss to disk (model_dir)
        if save_model and (loss <= best_loss):            
            y_hat_op = tf.identity(y_hat_op, name="y_hat_op")
            loss_op = tf.identity(loss_op, name="loss_op")
            
            inputs = {"x_ph": x_ph, "y_ph": y_ph}            
            outputs = {"y_hat_op": y_hat_op, "loss_op": loss_op}
            
            # if the directory already exists, delete before saving something to it
            if os.path.isdir(model_dir):
                shutil.rmtree(model_dir)
            tf.saved_model.simple_save(sess, model_dir, inputs, outputs)   
    ################################################################################
    #                               END OF YOUR CODE                               #
    ################################################################################
    
    return best_loss

# %% [markdown]
# ## Problem 3: Hyperparameter search (10 points)
#
# In the following we will call the `training` function multiple times with different hyperparameter configurations. We first define a handful of possible values for each hyperparameter and then test all combinations. This most basic version of hyperparameter optimization is called grid search.
#
# To save time, we will only train on a subsample of the training set (`num_training`) and evaluate the loss on a subsample of the validation set (`num_validation`).

# %%
def subsample_set(x, y, n):
    ################################################################################ 
    # Draws n examples without replacement from sets x, y
    # Arguments:
    # - x: input set
    # - y: label set
    # - n: number of examples drawn
    # Return values:
    # - x_subset: randomly selected x
    # - y_subset: corresponding labels of randomly selected x
    ################################################################################
    idx = np.arange(len(x))
    np.random.shuffle(idx)
    idx = idx[0 : n]
    return x[idx], y[idx]

# %%
def grid_search(x_train, y_train, x_val, y_val, dropout_rates, l2_lambdas, learning_rates,
                num_training, num_validation, num_epochs=5, batch_size=128):
    ################################################################################ 
    # Arguments:
    # - x_train: input training set
    # - y_train: label training set
    # - x_val: input validation set
    # - y_val: label validation set
    # - dropout_rates: dropout rates to try
    # - l2_lambdas: L2 lambda coefficients to try
    # - learning_rates: learning rates to try
    # - num_training: number of training examples used per model
    # - num_validation: number of validation examples used per model
    # - num_epochs: number of epochs to train
    # - batch_size: training mini-batch size
    # Return values:
    # - losses: losses for configurations tested
    ################################################################################
    losses = []
    
    pbar = tqdm(total = len(dropout_rates) * len(l2_lambdas) * len(learning_rates))
    for dropout_rate in dropout_rates:
        for l2_lambda in l2_lambdas:
            for learning_rate in learning_rates:
                # subsample training and validation sets
                subset_x_train, subset_y_train = subsample_set(x_train, y_train, num_training)
                subset_x_val, subset_y_val = subsample_set(x_val, y_val, num_validation)
                
                hyperparam_config = {'dropout_rate': dropout_rate,
                                     'l2': l2_lambda,
                                     'lr': learning_rate}
                
                best_loss = training(subset_x_train, subset_y_train,
                                     subset_x_val, subset_y_val,
                                     hyperparam_config,
                                     num_epochs,
                                     batch_size,
                                     save_model = False)
                
                losses.append([dropout_rate, l2_lambda, learning_rate, best_loss])
                pbar.update(1)
    pbar.close()
    return losses

# %%
# hyperparameter values to test
dropout_rates = [1.0 - 1e-3, 0.8, 0.5, 0.2]
l2_lambdas = [1e-03, 1e-06, 0]
learning_rates = [1e-1, 1e-3, 1e-5]

# static hyperparameters
num_training = 10000
num_validation = 2000
batch_size = 128
num_epochs = 10

# %%
param_result = grid_search(x_tr, y_tr, x_va, y_va, dropout_rates, l2_lambdas, learning_rates,
                           num_training, num_validation, num_epochs, batch_size)
df = pd.DataFrame(param_result,
                  columns = ['dropout rate', 
                             'L2 lambda',
                             'learning rate',
                             'validation loss']).pivot_table(values = ['validation loss'],
                                                             columns = ['L2 lambda'],
                                                             index = ['dropout rate', 'learning rate'])
df = df.round(3)
(df.style.background_gradient(cmap=sb.cubehelix_palette(start=.5, rot=-.75, as_cmap=True)))
# Out:
# HBox(children=(IntProgress(value=0, max=36), HTML(value=u'')))
# <style  type="text/css" >
#     #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row0_col0 {
#             background-color:  #32294e;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row0_col1 {
#             background-color:  #2d2141;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row0_col2 {
#             background-color:  #3e587b;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row1_col0 {
#             background-color:  #93c496;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row1_col1 {
#             background-color:  #d7dfc0;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row1_col2 {
#             background-color:  #b1d0a4;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row2_col0 {
#             background-color:  #2c1e3e;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row2_col1 {
#             background-color:  #2c1e3e;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row2_col2 {
#             background-color:  #3e587b;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row3_col0 {
#             background-color:  #32294e;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row3_col1 {
#             background-color:  #2d2141;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row3_col2 {
#             background-color:  #3e587b;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row4_col0 {
#             background-color:  #d7dfc0;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row4_col1 {
#             background-color:  #c2d6af;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row4_col2 {
#             background-color:  #c7d8b2;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row5_col0 {
#             background-color:  #32294e;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row5_col1 {
#             background-color:  #2c1e3e;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row5_col2 {
#             background-color:  #3e5a7c;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row6_col0 {
#             background-color:  #32294e;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row6_col1 {
#             background-color:  #2d2141;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row6_col2 {
#             background-color:  #3e587b;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row7_col0 {
#             background-color:  #54968d;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row7_col1 {
#             background-color:  #b5d1a6;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row7_col2 {
#             background-color:  #d7dfc0;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row8_col0 {
#             background-color:  #32294e;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row8_col1 {
#             background-color:  #2d2141;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row8_col2 {
#             background-color:  #3e5b7d;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row9_col0 {
#             background-color:  #32294e;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row9_col1 {
#             background-color:  #2d2141;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row9_col2 {
#             background-color:  #3e587b;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row10_col0 {
#             background-color:  #32294e;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row10_col1 {
#             background-color:  #2d2141;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row10_col2 {
#             background-color:  #3e5a7c;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row11_col0 {
#             background-color:  #2d2040;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row11_col1 {
#             background-color:  #2d2141;
#         }    #T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row11_col2 {
#             background-color:  #2c1e3e;
#         }</style>
# <table id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" colspan=3>validation loss</th>
#     </tr>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level1" >L2 lambda</th>
#         <th class="col_heading level1 col0" >0.0</th>
#         <th class="col_heading level1 col1" >1e-06</th>
#         <th class="col_heading level1 col2" >0.001</th>
#     </tr>    <tr>
#         <th class="index_name level0" >dropout rate</th>
#         <th class="index_name level1" >learning rate</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002level0_row0" class="row_heading level0 row0" rowspan=3>0.2</th>
#         <th id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002level1_row0" class="row_heading level1 row0" >1e-05</th>
#         <td id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row0_col0" class="data row0 col0" >0.693</td>
#         <td id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row0_col1" class="data row0 col1" >0.693</td>
#         <td id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row0_col2" class="data row0 col2" >0.696</td>
#     </tr>    <tr>
#         <th id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002level1_row1" class="row_heading level1 row1" >0.001</th>
#         <td id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row1_col0" class="data row1 col0" >0.539</td>
#         <td id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row1_col1" class="data row1 col1" >0.476</td>
#         <td id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row1_col2" class="data row1 col2" >0.577</td>
#     </tr>    <tr>
#         <th id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002level1_row2" class="row_heading level1 row2" >0.1</th>
#         <td id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row2_col0" class="data row2 col0" >0.706</td>
#         <td id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row2_col1" class="data row2 col1" >0.696</td>
#         <td id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row2_col2" class="data row2 col2" >0.696</td>
#     </tr>    <tr>
#         <th id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002level0_row3" class="row_heading level0 row3" rowspan=3>0.5</th>
#         <th id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002level1_row3" class="row_heading level1 row3" >1e-05</th>
#         <td id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row3_col0" class="data row3 col0" >0.693</td>
#         <td id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row3_col1" class="data row3 col1" >0.693</td>
#         <td id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row3_col2" class="data row3 col2" >0.696</td>
#     </tr>    <tr>
#         <th id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002level1_row4" class="row_heading level1 row4" >0.001</th>
#         <td id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row4_col0" class="data row4 col0" >0.49</td>
#         <td id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row4_col1" class="data row4 col1" >0.493</td>
#         <td id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row4_col2" class="data row4 col2" >0.563</td>
#     </tr>    <tr>
#         <th id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002level1_row5" class="row_heading level1 row5" >0.1</th>
#         <td id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row5_col0" class="data row5 col0" >0.693</td>
#         <td id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row5_col1" class="data row5 col1" >0.696</td>
#         <td id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row5_col2" class="data row5 col2" >0.695</td>
#     </tr>    <tr>
#         <th id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002level0_row6" class="row_heading level0 row6" rowspan=3>0.8</th>
#         <th id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002level1_row6" class="row_heading level1 row6" >1e-05</th>
#         <td id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row6_col0" class="data row6 col0" >0.693</td>
#         <td id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row6_col1" class="data row6 col1" >0.693</td>
#         <td id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac110002row6_col2" class="data row6 col2" >0.696</td>
#     </tr>    <tr>
#         <th id="T_35e8d3dc_3fb1_11e9_b7fe_0242ac11

# %% [markdown]
# ### Questions
#
# #### Question 3.1
#
# Based on your observation, is the performance impacted by only one hyper-parameter or several? Describe your observation to support your conclusion.
#
# <span style="text-transform: uppercase; color: #408080; font-size: bigger; font-weight: bold;">Your (short) answer:</span>

# %% [markdown]
# The performance seems to be most impacted by just the learning rate, but specific combinations of the dropout rate and validation loss are necessary to produce the best performance. The learning rate of 0.001 seems to perform best with lower dropout rates, performing most poorly at a high dropout rate of 0.999. The best combination is the dropout rate of 0.2, learning rate of 0.001, and validation loss of 1e-6.

# %% [markdown]
# #### Question 3.2
#
# What have you observed when the L2 coefficient is 1e-03? What do you think will happen if we have an even larger coefficient, and why?
#
# <span style="text-transform: uppercase; color: #408080; font-size: bigger; font-weight: bold;">Your (short) answer:</span>

# %% [markdown]
# When the L2 coefficient is 1e-03, the performance of the model is the best. When computing the loss function, a larger L2 coefficient gives higher weight to the weight matrices of the convolutional layer and two fully connected layer. This is a weighting above the normal loss comparison of the real labels and predicted labels. With a higher L2, such as 0.1, the model performs worse, and this is because the weights of the layers are being weighted more heavily in the loss function than the actual accuracy of the model, which is vitally important to the improving the model's performance over subsequent optimizations. With a lower L2, the weights of the convolutional and fully connected layers are deemed less important for the loss function and thus the model is not able to learn as well as with a coefficient of 1e-3, hence the lower performance.

# %% [markdown]
# #### Question 3.3
#
# - Assuming each hyper-parameter has a constant number of choices to pick from, how fast does the search space grow as a function of the number of hyper-parameters to consider?
# - Can you think of smarter ways than grid search to explore the hyperparameter space?
#
# <span style="text-transform: uppercase; color: #408080; font-size: bigger; font-weight: bold;">Your (short) answer:</span>

# %% [markdown]
# The search space grows exponentially as a function of the number of hyperparameters n. If each hyperparameter has k choices of values, then the search space grows with O(k^n). For example if you have 3 values to consider for each parameter, and you have 1 parameter --> that's 3 models to try. If you have 3 values to consider, and 2 parameters --> that's 9 models to try, etc.
#
# A grid search is the naive way to explore the hyperparameter space, so instead, you could randomly pick sets of hyperparameter values to try, and after your first round of trying a couple, use the set that gave you the best performance. Then you could fine-tune those values to get an even better performance. The danger with this is that you may settle into a local minimum that is not the global minimum, but it may be much more time efficient.

# %% [markdown]
# ## Problem 4: Evaluate best model on test set (10 points)
#
# Now let's train the network with the best hyper-parameters on the **whole** training set:

# %%
best_model_dir = "models/best_model"
################################################################################
#                            BEGINNING OF YOUR CODE                            #
################################################################################
# change dropout rate, L2 coefficient, and learning rate to
# best values (according to grid search above):
hyperparam_config = {'dropout_rate': 0.2,
                     'l2': 1e-6,
                     'lr': 0.001}
################################################################################
#                               END OF YOUR CODE                               #
################################################################################
validation_loss = training(x_tr, y_tr, x_va, y_va,
                           hyperparam_config, num_epochs, batch_size, save_model=True, model_dir=best_model_dir)
print('validation loss:', validation_loss)
# Out:
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: models/best_model/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: models/best_model/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: models/best_model/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: models/best_model/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: models/best_model/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: models/best_model/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: models/best_model/saved_model.pb
# ('validation loss:', 0.3241397)

# %% [markdown]
# Implement the `predict` function. Restoring a previously saved model is described [here](https://www.tensorflow.org/guide/saved_model) and [here](https://stackoverflow.com/questions/33759623/tensorflow-how-to-save-restore-a-model/50852627#50852627).
#
# Useful functions:
# - [tf.saved_model.load](https://www.tensorflow.org/api_docs/python/tf/saved_model/load)

# %%
def predict(x, model_dir):
    ################################################################################
    # load a trained model and predict y_hat for examples in x
    # Arguments
    # - x: one-hot encoded DNA input data of shape [?, 1, 101, 4]
    # - model_dir: where the model was saved
    # Return values: 
    # - y_hat: class probabilities of examples in x
    ################################################################################
    #                            BEGINNING OF YOUR CODE                            #
    ################################################################################

    from tensorflow.python.saved_model import tag_constants  

    # set up a session to evaluate our computational graphs
    graph = tf.Graph()
    with graph.as_default():
        with tf.Session() as sess:
          # initialize the variables and reload the saved inputs and outputs
            tf.global_variables_initializer()
            tf.saved_model.loader.load(sess, [tag_constants.SERVING], model_dir)
            x_ph = graph.get_tensor_by_name('x_ph:0')
            y_ph = graph.get_tensor_by_name('y_ph:0')
            y_hat_op = graph.get_tensor_by_name('y_hat_op:0')
            loss_op = graph.get_tensor_by_name('loss_op:0')

            # determine y-hat from these variables
            y_hat = y_hat_op.eval(feed_dict = {x_ph: x})

    ################################################################################
    #                               END OF YOUR CODE                               #
    ################################################################################
    return y_hat

# %% [markdown]
# ### Model evalutation
#
# We will evaluate the trained model using the `predict` function defined above.

# %%
y_hat_test = predict(x_te, best_model_dir)
# Out:
# INFO:tensorflow:Restoring parameters from models/best_model/variables/variables

# %% [markdown]
# #### ROC curve
#
# The area under the ROC curve (auROC) evaluated on the test set should be around 0.94.

# %%
def plot_roc_curve(y, y_hat):

    fpr, tpr, _ = sklearn.metrics.roc_curve(y[:, 0], y_hat[:, 0])
    roc_auc = sklearn.metrics.auc(fpr, tpr)

    plt.figure(figsize=(10,10))
    plt.rcParams.update({'font.size': 14})
    plt.plot(fpr, tpr, color='darkorange',
             lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC curve')
    plt.legend(loc="lower right")
    plt.show()

# %%
plot_roc_curve(y_te, y_hat_test)
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# #### Precision-Recall curve

# %%
def plot_pr_curve(y, y_hat):
    precision, recall, _ = sklearn.metrics.precision_recall_curve(y[:, 0], y_hat[:, 0])
    pr_auc = sklearn.metrics.auc(recall, precision)
    f1 = sklearn.metrics.f1_score(y[:, 0], np.round(y_hat[:, 0]))
    
    plt.figure(figsize=(10,10))
    plt.rcParams.update({'font.size': 14})
    plt.plot(recall, precision, color='darkorange',
             lw=2, label='PR curve (area = {0}, $F_1 = {1}$'.format(
              round(pr_auc, 2), round(f1, 2)))

    f_scores = np.linspace(0.2, 0.8, num=4)
    lines = []
    labels = []
    for f_score in f_scores:
        x = np.linspace(0.01, 1)
        y = f_score * x / (2 * x - f_score)
        l, = plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.2)
        plt.annotate('$F_1 = {0:0.1f}$'.format(f_score), xy=(0.87, y[45] + 0.02))

    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.0])
    plt.xlim([0.0, 1.0])
    plt.title('Precision-Recall curve')
    plt.legend(loc="lower left")
    plt.show()

# %% [markdown]
# The area under the PR curve should be around 0.95 and $F_1 	\approx 0.87$.

# %%
plot_pr_curve(y_te, y_hat_test)

# %% [markdown]
# ## Problem 5: CNN + RNN (6.874 only - 20 points out of 120 points)
#
# (Students enrolled in 6.802, 20.390, 20.490 or HST.506 can also submit a solution for this problem - for an extra 20 points)
#
# The binding of some transcription factors depends on the distance-specific existence of co-binding factors. Recall from class that RNNs are good at capturing dependencies between different positions in the input. Thus we are going to explore whether a CNN-RNN hybrid model could achieve a better performance than a regular CNN in classifying motif pairs (NFKB and CTCF in this problem) with variable spacing (10 - 20bp) from the same motif pairs with random spacing in a 101bp sequence.
#
# **Note**:
# - You can use the best CNN hyperparameters obtained from the previous sections for the CNN part of your model.
# - You should be able to achieve an auROC around 0.85 for the CNN and 0.87 for the CNN + RNN model.

# %%
x_tr_rnn, y_tr_rnn, x_va_rnn, y_va_rnn, x_te_rnn, y_te_rnn = load_data(prefix='rnn_', path='./')
print(x_tr_rnn.shape, x_va_rnn.shape, x_te_rnn.shape)
# Out:
# ((32400, 1, 101, 4), (3600, 1, 101, 4), (4000, 1, 101, 4))

# %% [markdown]
# ### Define model and loss
#
# Adapt the `cnn_model` from before by adding a one-layer LSTM RNN (with 48 units) after the max-pooling layer (instead of the fully-connected layer). We will use the softmax of the output of the last LSTM cell as the probability of the two classes. We will ignore regularization and hyperparameter search for this problem (unless you want to explore that).
#
# Useful functions:
# - [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d)
# - [tf.nn.bias_add](https://www.tensorflow.org/api_docs/python/tf/nn/bias_add)
# - [tf.nn.relu](https://www.tensorflow.org/api_docs/python/tf/nn/relu)
# - [tf.nn.max_pool](https://www.tensorflow.org/api_docs/python/tf/nn/max_pool)
# - [tf.squeeze](https://www.tensorflow.org/api_docs/python/tf/squeeze)
# - [tf.transpose](https://www.tensorflow.org/api_docs/python/tf/transpose)
# - [tf.split](https://www.tensorflow.org/api_docs/python/tf/split)
# - [tf.nn.rnn_cell.LSTMCell](https://www.tensorflow.org/api_docs/python/tf/nn/rnn_cell/LSTMCell)
# - [tf.nn.static_rnn](https://www.tensorflow.org/api_docs/python/tf/nn/static_rnn)
# - [tf.matmul](https://www.tensorflow.org/api_docs/python/tf/linalg/matmul)
# - [tf.nn.softmax](https://www.tensorflow.org/api_docs/python/tf/nn/softmax)

# %%
def cnn_rnn_model(x_ph):
    ################################################################################ 
    # Implement a CNN-RNN hybrid
    # Arguments:
    # - x_ph: one-hot encoded DNA input data / placeholder of shape [?, 1, 101, 4]
    # Return values:
    # - y_hat_op: class probabilities operator (our predicted y, sigmoid(z_op)) of shape [?, 2]
    # - z_op: unscaled log probabilities operator (output of last matrix multiplication,
    #      before activation function) of shape [?, 2]
    ################################################################################
    # CNN hyperparameters
    conv_filter_height = 1
    conv_filter_width = 11
    in_channels = 4
    out_channels = 32
    
    max_pool_stride = 2
    
    # RNN hyperparameters
    rnn_units = 48
    unroll_length = 51 # complete sequence length (101 after pool stride of 2)
    ################################################################################
    #                            BEGINNING OF YOUR CODE                            #
    ################################################################################
    
    # initialize first weight matrices   
    conv_weight_matrix_size = [conv_filter_height, conv_filter_width, in_channels, out_channels]
    conv_weights = tf.Variable(tf.truncated_normal(conv_weight_matrix_size, mean=0.0, stddev=0.01))

    # 1) first convolutional layer with 32 kernels of width 11 & height 1, step size 1, ReLu activation
    # also has zero padding and ReLu activation
    strides = 2
    conv1 = tf.nn.conv2d(x_ph, conv_weights, strides=[1, strides, strides, 1], padding='SAME') 
    conv1_bias = tf.Variable(tf.constant(0.1, shape = [out_channels]))
    conv1 = tf.nn.bias_add(conv1, conv1_bias)
    conv1 = tf.nn.relu(conv1)
    
    # 2) one max pooling layer with pool size of 2
    conv1 = tf.nn.max_pool(conv1, ksize=[1, max_pool_stride, max_pool_stride, 1], strides=[1, 1, 1, 1], padding='SAME')
    
    # 3) "squeeze" to prepare for the LSTM RNN
    squeezed = tf.squeeze(conv1)
    rnn = tf.transpose(squeezed, [1, 0, 2])
    rnn = tf.reshape(rnn, [-1, out_channels])
    rnn = tf.split(rnn, unroll_length, 0)
    
    # 4) one-layer LSTM RNN (with 48 units)
    lstm_cell = tf.nn.rnn_cell.BasicLSTMCell(num_units=rnn_units)
    outputs, states = tf.nn.static_rnn(lstm_cell, rnn, dtype = tf.float32)
    num_classes = 2
    rnn_weights = tf.Variable(tf.truncated_normal([rnn_units, num_classes], mean=0.0, stddev=0.01))
    rnn_bias = tf.Variable(tf.random_normal([num_classes]))
    lstm = tf.add(tf.matmul(outputs[-1], rnn_weights), rnn_bias)
    
    # 5) a fully connected layer with softmax activation
    full_bias = tf.Variable(tf.constant(0.1, shape =[max_pool_stride]))
    full_weight_matrix_size = [num_classes, max_pool_stride]
    full_weights = tf.Variable(tf.truncated_normal(full_weight_matrix_size, mean=0.0, stddev=0.01))
    
    # 6) use the softmax of the output of the last LSTM cell as the probability of the two classes
    z_op = tf.add(tf.matmul(lstm, full_weights), full_bias)
    y_hat_op = tf.nn.softmax(z_op)
        
    ################################################################################
    #                               END OF YOUR CODE                               #
    ################################################################################
    return y_hat_op, z_op

# %% [markdown]
# `cnn_rnn_loss` is `cnn_loss` without the $L_2$ regularization term.

# %%
def cnn_rnn_loss(z_op, y_ph):
    ################################################################################ 
    # Implement a loss operator, which calculates sigmoid cross entropy loss 
    # Arguments:
    # - z_op: unscaled log probabilities (output of last layer) of shape [?, 2]
    # - y_ph: labels / placeholder of shape [?, 2]
    # Return values:
    # - loss_op: the loss operator
    ################################################################################
    #                            BEGINNING OF YOUR CODE                            #
    ################################################################################
    
    # Original loss function
    loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits = z_op, labels = y_ph))

    ################################################################################
    #                               END OF YOUR CODE                               #
    ################################################################################
    return loss_op

# %% [markdown]
# The training loop in `cnn_rnn_training` should be identical to the training loop in `cnn_training`.

# %%
def cnn_rnn_training(x_train, y_train, x_val, y_val, num_epochs, batch_size,
             save_model=True, model_dir='models/best_model'): 
    ################################################################################
    # Arguments:
    # - x_train: input training set
    # - y_train: label training set
    # - x_val: input validation set
    # - y_val: label validation set
    # - hyperparam_config: a dictionary that stores a hyperparameter configuration,
    #                      including:
    #                      - "dropout_rate": dropout rate (1 - keep probability),
    #                      - "l2": coefficient lambda for L2 regularization,
    #                      - "lr": learning rate for RMSProp optimizer
    # - num_epochs: number of epochs to train
    # - batch_size: training mini-batch size
    # - best_model_dir: location where model will be saved
    # Return values:
    # - best_loss: best validation loss
    ################################################################################
    tf.reset_default_graph()
    
    # define input and output placeholders
    # TF uses NHWC: the data is stored in the order of [batch, in_height, in_width, in_channels]
    # DNA is one-dimensional (height = 1, width = 101) with four channels for the four bases A, C, G, T
    x_ph = tf.placeholder("float", [None, 1, SEQ_LEN, NUM_BASES], name="x_ph")
    y_ph = tf.placeholder("float", [None, NUM_CLASSES], name="y_ph")

    # model
    y_hat_op, z_op = cnn_rnn_model(x_ph)
    
    # loss
    loss_op = cnn_rnn_loss(z_op, y_ph)

    # optimizer
    optimizer_op = tf.train.RMSPropOptimizer(0.001, 0.9).minimize(loss_op)
     
    # Implement training loop
    # - loop through training data num_epochs times
    # - after each epoch, calculate loss on validation set (x_val, y_val)
    # - if save_model: save model with lowest validation loss to disk (model_dir)
    # - (delete previously best model)
    # - return lowest validation loss
    ################################################################################
    #                            BEGINNING OF YOUR CODE                            #
    ################################################################################
    
    # initialize variables & import necessary things
    from tensorflow.python.saved_model import tag_constants
    best_loss = 100000000000
    
    # set up a session to evaluate the computational graph
    with tf.Session() as sess:
      sess.run(tf.global_variables_initializer())
      
      # loop through training data num_epochs times
      for epoch in range(num_epochs): 
        batch_nums = int(x_train.shape[0] / batch_size)

        # loop through each of the mini-batches to optimize the model
        for step in range(batch_nums):
          offset = (step * batch_size) % (x_train.shape[0] - batch_size)
          batch_x = x_train[offset:(offset + batch_size), :]
          batch_y = y_train[offset:(offset + batch_size)]
          _, batch_loss = sess.run([optimizer_op, loss_op], feed_dict = {x_ph: batch_x, y_ph: batch_y})
        
        # calculate the loss after every epoch
        loss = sess.run(loss_op, feed_dict={x_ph: x_val, y_ph: y_val})
        best_loss = min(loss, best_loss)
        
        # if save_model: save model with lowest validation loss to disk (model_dir)
        if save_model and (loss <= best_loss):            
            y_hat_op = tf.identity(y_hat_op, name="y_hat_op")
            loss_op = tf.identity(loss_op, name="loss_op")
            
            inputs = {"x_ph": x_ph, "y_ph": y_ph}            
            outputs = {"y_hat_op": y_hat_op, "loss_op": loss_op}
            
            # delete the output directory if it already exists
            if os.path.isdir(model_dir):
                shutil.rmtree(model_dir)
            tf.saved_model.simple_save(sess, model_dir, inputs, outputs)
    
    ################################################################################
    #                               END OF YOUR CODE                               #
    ################################################################################
    return best_loss

# %% [markdown]
# ### Performance evaluation
#
# #### LSTM

# %%
best_rnn_model_dir = "models/best_model_rnn"
validation_loss = cnn_rnn_training(x_tr_rnn, y_tr_rnn, x_va_rnn, y_va_rnn, num_epochs, batch_size, save_model = True,
                                   model_dir = best_rnn_model_dir)
print('validation loss:', validation_loss)
# Out:
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: models/best_model_rnn/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: models/best_model_rnn/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: models/best_model_rnn/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: models/best_model_rnn/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: models/best_model_rnn/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: models/best_model_rnn/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: models/best_model_rnn/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: models/best_model_rnn/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: models/best_model_rnn/saved_model.pb
# ('validation loss:', 0.39436385)

# %% [markdown]
# We can reuse the `predict` function from before.

# %%
y_hat_test_rnn = predict(x_te_rnn, best_rnn_model_dir)
# Out:
# INFO:tensorflow:Restoring parameters from models/best_model_rnn/variables/variables

# %% [markdown]
# #### CNN

# %%
best_cnn_model_dir = "models/best_model_cnn"
################################################################################
#                            BEGINNING OF YOUR CODE                            #
################################################################################
# change dropout rate, L2 coefficient, and learning rate to
# best values (according to grid search from previous problem):
hyperparam_config = {'dropout_rate': 0.2,
                     'l2': 1e-6,
                     'lr': 0.001}
################################################################################
#                               END OF YOUR CODE                               #
################################################################################
validation_loss = training(x_tr_rnn, y_tr_rnn, x_va_rnn, y_va_rnn,
                           hyperparam_config, num_epochs, batch_size, save_model=True, model_dir=best_cnn_model_dir)
print('validation loss:', validation_loss)
# Out:
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: models/best_model_cnn/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: models/best_model_cnn/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: models/best_model_cnn/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: models/best_model_cnn/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: models/best_model_cnn/saved_model.pb
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: models/best_model_cnn/saved_model.pb
# ('validation loss:', 0.43631625)

# %%
y_hat_test_cnn = predict(x_te_rnn, best_cnn_model_dir)
# Out:
# INFO:tensorflow:Restoring parameters from models/best_model_cnn/variables/variables

# %% [markdown]
# #### Model comparison

# %%
def plot_roc_curve(y, y_hat, labels):
    # RNN
    fpr0, tpr0, _ = sklearn.metrics.roc_curve(y[0][:, 0], y_hat[0][:, 0])
    roc_auc0 = sklearn.metrics.auc(fpr0, tpr0)
    
    # CNN
    fpr1, tpr1, _ = sklearn.metrics.roc_curve(y[1][:, 0], y_hat[1][:, 0])
    roc_auc1 = sklearn.metrics.auc(fpr1, tpr1)

    plt.figure(figsize=(10,10))
    plt.rcParams.update({'font.size': 14})
    plt.plot(fpr0, tpr0, color='darkorange',
             lw=2, label=labels[0] + ' (area = %0.2f)' % roc_auc0)
    plt.plot(fpr1, tpr1, color='blue',
             lw=2, label=labels[1] + ' (area = %0.2f)' % roc_auc1)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC curve')
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# CNN auROC was around 0.85, and for LSTM around 0.87.

# %%
plot_roc_curve([y_te_rnn, y_te_rnn], [y_hat_test_rnn, y_hat_test_cnn], ["CNN + LSTM", "CNN"])

# %%
def plot_pr_curve(y, y_hat, labels):
    # RNN
    precision0, recall0, _ = sklearn.metrics.precision_recall_curve(y[0][:, 0], y_hat[0][:, 0])
    pr_auc0 = sklearn.metrics.auc(recall0, precision0)
    f10 = sklearn.metrics.f1_score(y[0][:, 0], np.round(y_hat[0][:, 0]))
    
    # CNN
    precision1, recall1, _ = sklearn.metrics.precision_recall_curve(y[1][:, 0], y_hat[1][:, 0])
    pr_auc1 = sklearn.metrics.auc(recall1, precision1)
    f11 = sklearn.metrics.f1_score(y[1][:, 0], np.round(y_hat[1][:, 0]))
    
    plt.figure(figsize=(10,10))
    plt.rcParams.update({'font.size': 14})
    plt.plot(recall0, precision0, color='darkorange',
             lw=2, label=labels[0] + ' (area = {0}, $F_1 = {1}$)'.format(round(pr_auc0, 2), round(f10, 2)))
    plt.plot(recall1, precision1, color='blue',
             lw=2, label=labels[1] + ' (area = {0}, $F_1 = {1}$)'.format(round(pr_auc1, 2), round(f11, 2)))

    f_scores = np.linspace(0.2, 0.8, num=4)
    lines = []
    labels = []
    for f_score in f_scores:
        x = np.linspace(0.01, 1)
        y = f_score * x / (2 * x - f_score)
        l, = plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.2)
        plt.annotate('$F_1 = {0:0.1f}$'.format(f_score), xy=(0.87, y[45] + 0.02))

    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.0])
    plt.xlim([0.0, 1.0])
    plt.title('Precision-Recall curve')
    plt.legend(loc="lower left")
    plt.show()

# %% [markdown]
# CNN auPR was around 0.79, and for LSTM around 0.81.

# %%
plot_pr_curve([y_te_rnn, y_te_rnn], [y_hat_test_rnn, y_hat_test_cnn], ["CNN + LSTM", "CNN"])
